# %%
import pandas as pd
import numpy as np
from kaggle.api.kaggle_api_extended import KaggleApi
import os

# %%
#Download 
api = KaggleApi()
api.authenticate() #a kaggle API token can be created via the Account section of your Kaggle profile
data_path = ''.join((os.getcwd(), '\data')) 
#Be aware the while setting `quiet` to false will display download updates, it prints a new line for each update
api.dataset_download_files('allen-institute-for-ai/CORD-19-research-challenge', path=data_path, quiet=True, unzip=True)
# Out:
#   0%|          | 0.00/646M [00:00<?, ?B/s]
# ...
#   0%|          | 1.00M/646M [00:00<02:01, 5.58MB/s]
#
#   0%|          | 3.00M/646M [00:00<01:42, 6.55MB/s]
#
#   1%|          | 4.00M/646M [00:00<01:32, 7.30MB/s]
#
#   1%|          | 5.00M/646M [00:00<01:24, 7.92MB/s]
#
#   1%|          | 6.00M/646M [00:00<01:19, 8.40MB/s]
#
#   1%|          | 7.00M/646M [00:00<01:16, 8.76MB/s]
#
#   1%|          | 8.00M/646M [00:00<01:13, 9.05MB/s]
#
#   1%|▏         | 9.00M/646M [00:01<01:12, 9.26MB/s]
#
#   2%|▏         | 10.0M/646M [00:01<01:10, 9.41MB/s]
#
#   2%|▏         | 11.0M/646M [00:01<01:09, 9.53MB/s]
#
#   2%|▏         | 12.0M/646M [00:01<01:09, 9.63MB/s]
#
#   2%|▏         | 13.0M/646M [00:01<01:11, 9.26MB/s]
#
#   2%|▏         | 15.0M/646M [00:01<01:08, 9.70MB/s]
#
#   2%|▏         | 16.0M/646M [00:01<01:08, 9.68MB/s]
#
#   3%|▎         | 17.0M/646M [00:01<01:07, 9.81MB/s]
#
#   3%|▎         | 18.0M/646M [00:01<01:08, 9.64MB/s]
#
#   3%|▎         | 19.0M/646M [00:02<01:08, 9.57MB/s]
#
# ...
